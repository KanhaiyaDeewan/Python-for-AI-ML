# %%
name = "ram"
print(name)
# Out:
# ram

# %%
age = 25
print(age)
# Out:
# 25

# %%
fruits=["apple" , "bannna" , "Cherry"]
print(fruits)
# Out:
# ['apple', 'bannna', 'Cherry']

# %%
x =10
print(10)
# Out:
# 10

# %%
del x

# %%
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(x)
#
# NameError: name 'x' is not defined

# %%
fruits = ["apple" , "banana" , "cheery"]
print(fruits)

del fruits[1]
print(fruits)
# Out:
# ['apple', 'banana', 'cheery']
# ['apple', 'cheery']

# %%
#store user information
user_name = "Arvind"
User_age =30
user_email = "arvinda1234@gmail.com"

# display user information
print("Name:", user_name)
print("age:", User_age)
print("Email:", user_email)


#Delete user email after sending a notifications

print("Email:" , user_email)
# Out:
# Name: Arvind
# age: 30
# Email: arvinda1234@gmail.com
# Email: arvinda1234@gmail.com

# %%
#addition(+=)
x = 10
x+=5  #x = x+5
print(x)
# Out:
# 15

# %%
y =20
#y=y-3
y-=3

# %%
print(y)
# Out:
# 17

# %%
c=10
c%=3  #c =c%3
print(c)
# Out:
# 1

# %%
#updating a counting
cart_items = 5

#add 3 more items
#cart_items =cart_items + 3
cart_items +=3
#remove 2 items
#cart_items =cart_items - 2

cart_items -= 2

print("items cart_items :" , cart_items )
# Out:
# items cart_items : 6

# %%
fruits=["apples" , "bannana" , "cherry"]

#check if banna is in the list
print("bannana" in fruits)
print("mango" in fruits)

#check if banna is not the list
print("grape"  not in fruits)
print("bannana" not in fruits)
# Out:
# True
# False
# True
# False

# %%
numbers=(1,2,3,4,5,6)
print(3 in numbers)
print(6 not in numbers)
# Out:
# True
# False

# %%
message="Hello,World!"
print("Hello" in message)
print("World" not in message)
# Out:
# True
# False

# %%
x=5
print(1<x<10)
# Out:
# True

# %%
z=7
print(1<z<10 and z%2==1)
# Out:
# True

# %%
z=6
print(1<z<10 and z%2==1)
# Out:
# False

# %%
y=10
print(5<y<=10)
# Out:
# True

# %%
#lower
text="Hello World!"
print(text.lower())
# Out:
# hello world!

# %%
print(text.upper())
# Out:
# HELLO WORLD!

# %%
text="hello , world!"
print(text.capitalize())
# Out:
# Hello , world!

# %%
print(text.title())
# Out:
# Hello , World!

# %%
#Hello , World!
#hELLO , wORLD
text="Hello World!"
print(text.swapcase())
# Out:
# hELLO wORLD!

# %%
#islower()
text="hello"
print(text.islower())
# Out:
# True

# %%
#islower()
text="Hello"
print(text.islower())
# Out:
# False

# %%
#isupper()
text="HELLO"
print(text.isupper())
# Out:
# True

# %%
#issupper()
text="hELLO"
print(text.isupper())
# Out:
# False

# %%
text="1234a"
print(text.isnumeric())
# Out:
# False

# %%
text="1234"
print(text.isnumeric())
# Out:
# True

# %%
text="123"
print(text.isdigit())
# Out:
# True

# %%
text="Hello"
print(text.isalpha())
# Out:
# True

# %%
text="Hello1"
print(text.isalpha())
# Out:
# False

# %%
text="Hello123"
print(text.isalpha())
# Out:
# False

# %%
text="Hello"
print(text.isalnum())
# Out:
# True

# %%
text="Heelo123"
print(text.isalnum())
# Out:
# True

# %%
text="Heelo123"
print(text.isalnum())
# Out:
# True

# %%
text="Heel@o123"
print(text.isalnum())
# Out:
# False

# %%
#        HELLo, WORLD!
#HELLO , WORLD!
text="                             Hello , world!"
print(text.strip())
# Out:
# Hello , world!

# %%
text="____________________________Hello , World!_________"
print(text)
# Out:
# ____________________________Hello , World!_________

# %%
text="____________________________Hello , World!_________"
print(text.strip("_"))
# Out:
# Hello , World!

# %%
text="____________________________Hello , World!_________"
print(text.lstrip("_"))
# Out:
# Hello , World!_________

# %%
text="____________________________Hello , World!_________"
print(text.rstrip("_"))
# Out:
# ____________________________Hello , World!

# %%
text="HELLO world!"
print(text.startswith("HELLO"))
# Out:
# True

# %%
text="2HELLO world!"
print(text.startswith("HELLO"))
# Out:
# False

# %%
text="HELLO world!"
print(text.endswith("world!"))
# Out:
# True

# %%
text="HELLO world!"
print(text.endswith("hello!"))
# Out:
# False

# %%
text="Hello, world!"
print(text.count("l"))
# Out:
# 3

# %%
text="Hello world!"
print(text.index("world!"))
# Out:
# 6

# %%
text="Hello world!"
print(text.replace("world!" , "python!"))
# Out:
# Hello python!
