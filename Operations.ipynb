# %%
print("hello world!")
# Out:
# hello world!

# %%
print(kanhai)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(kanhai)
#
# NameError: name 'kanhai' is not defined

# %%
print(7)
# Out:
# 7

# %%
print(7.7)
# Out:
# 7.7

# %%
print(True)
# Out:
# True

# %%
print([1,2,3,4,5,6,7,8,8])
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 8]

# %%
print({1,2,3,4,5,5,6})
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
print({'name': 'krish' ,"age":18,"play":'hocky'})
# Out:
# {'name': 'krish', 'age': 18, 'play': 'hocky'}

# %%
print({'name': 'krih' ,"age":18,"play":'hocky'})
# Out:
# {'name': 'krih', 'age': 18, 'play': 'hocky'}

# %%
print({'name': 'ginni' ,"age":18,"play":'hocky'})
# Out:
# {'name': 'ginni', 'age': 18, 'play': 'hocky'}

# %%
## the calue of a is 5
a = 5
print(a)
# Out:
# 5

# %%
a = str(5)
print(a)
# Out:
# 5

# %%
a = float(5)
print(a)
# Out:
# 5.0

# %%
Sudh = 5.99
s = str(Sudh)
print(s)
# Out:
# 5.99

# %%
type(s)
# Out:
# str

# %%
a = 'tiger'
kanha = (a)
b = "kishore"
c= True
d = 4+6j
print(kanha , b ,a,sep ='/')
print(c,d)
# Out:
# tiger/kishore/tiger
# True (4+6j)

# %%
a = 5.6
a = int(a)
_ = 'kish'
print(_)



print(a)
# Out:
# kish
# 5

# %%
n =input("enter intiger")
# Out:
# enter intiger kanhaiya.iitm@gmail.com

# %%
print(n)
# Out:
# kanhaiya.iitm@gmail.com

# %%
fnum = int(input("Enter your First No"))
snum = int(input("Enter your Second No"))
result = fnum + snum
print(result)
print(fnum)
print(snum)
type(fnum)
type(snum)
# Out:
# Enter your First No 456
# Enter your Second No 567
# 1023
# 456
# 567
# int

# %%
a = (5+6.6)
type(a)
b = int(a)
print(b)
type(b)
# Out:
# 11
# int

# %%
ch = ([1,2,3,(3+6j),True,5.5,5.9,'sudh'])
print(ch)
# Out:
# [1, 2, 3, (3+6j), True, 5.5, 5.9, 'sudh']

# %%
ch[3]
# Out:
# (3+6j)

# %%
ch[3].real
# Out:
# 3.0

# %%
ch[3].imag
# Out:
# 6.0

# %%
p = 6+8j
p.imag,p.real
# Out:
# (8.0, 6.0)

# %%
A = 'keshav is going to market'
b = 'price is too much high'
c = 6
print(A+b+c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[90], line 4
#       2 b = 'price is too much high'
#       3 c = 6
# ----> 4 print(A+b+c)
#
# TypeError: can only concatenate str (not "int") to str

# %%
A = 'keshav is going to market '
b = ('the price of cloth  too much high ')
c = str(7)
print(A+b+c)
# Out:
# keshav is going to market the price of cloth  too much high 7

# %%
a = True + False
print(a)
# Out:
# 1

# %%
print(False-0)
# Out:
# 0

# %%
kanh = True - False + True
print(kanh)
# Out:
# 2

# %%
print('value:', kanh)
# Out:
# value: 2

# %%
###operators

# %%
print(2+3)
print(9-7)
print(15%4)
print(11//4)
print(9*4)
print(5/5)
print(2**4)
# Out:
# 5
# 2
# 3
# 2
# 36
# 1.0
# 16

# %%
###Relational arguments
print(2>3)
print(4>3)
print(3>=4)
print(5<=7)
print(4>=4)
print(5<=3)
print(2 != 2)
print(2==9)
print(2 != 3)
print( 4 == 4)
# Out:
# False
# True
# False
# True
# True
# False
# False
# False
# True
# True

# %%
##logical operator
print(5&6)
print (5 and 6)
print(5 or 6)
print(1 or False)
print(1 and False)
print(2 and True)
print( True or False)
print (not True)
print(not 1)
# Out:
# 4
# 6
# 5
# 1
# False
# True
# True
# False
# False

# %%
###Bitwise

# %%
##Assignment operator
a = 2
a +=2
print(a)
a -=2
print(a)
# Out:
# 4
# 2

# %%
a =16
a %=4 
print(a)
b = 15
b //= 12
print(b)
b == a
# Out:
# 0
# 1
# False

# %%
a == 0
# Out:
# True

# %%
a1 = 3
a == 2 # True or False
print(a)
print(a1)
# Out:
# 0
# 3

# %%
a = "delhi"
print('d' in a)
print('C' in 'delhi')
f =([1,2,3,4,'hello'])
print(f[4] in f)
print(4 in f)
# Out:
# True
# False
# True
# True
