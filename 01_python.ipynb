# %%
print("this is my first Python")
# Out:
# this is my first Python

# %%
1+2
# Out:
# 3

# %%
3/7
# Out:
# 0.42857142857142855

# %%
1+2
# Out:
# 3

# %%
a = 10

# %%
kanha = 2345

# %%
kanha
# Out:
# 2345

# %%
type(a)
# Out:
# int

# %%
b =45.77

# %%
type(b)
# Out:
# float

# %%
c = "kanha"

# %%
type(c)
# Out:
# str

# %%
d = 5+6j

# %%
type(d)
# Out:
# complex

# %%
e = 'kanh'

# %%
type(e)
# Out:
# str

# %%
n = "ncjsjdsdjilknsasjkjjkljbjsfsfsfsjkjkjojjjllkjhadj"

# %%
g = True

# %%
type(g)
# Out:
# bool

# %%
*a = 67
# Out:
#   Cell In[26], line 1
#     *a = 67
#     ^
# SyntaxError: starred assignment target must be in a list or tuple

# %%
_a = 56

# %%
a = 34

# %%
a
# Out:
# 34

# %%
a =5657
b ="kanha"
c =6+7j
d = True
d = 576.98

# %%
a
# Out:
# 5657

# %%
a1 = 9877

# %%
a+a1
# Out:
# 15534

# %%
a,b,c,d,e = 234,"kumar" , 4+6j , False , 579.77

# %%
a
# Out:
# 234

# %%
c
# Out:
# (4+6j)

# %%
e
# Out:
# 579.77

# %%
c
# Out:
# (4+6j)

# %%
type(c)
# Out:
# complex

# %%
c.imag
# Out:
# 6.0

# %%
c.real
# Out:
# 4.0

# %%
a = "kanh"

# %%
a + "4"
# Out:
# 'kanh4'

# %%
a + str(5)
# Out:
# 'kanh5'

# %%
True + True
# Out:
# 2

# %%
True - False
# Out:
# 1

# %%
1 + True
# Out:
# 2

# %%
input()
# Out:
#  fsdlkjnahiyaa
# 'fsdlkjnahiyaa'

# %%
a = "kanha"

# %%
a = input()
# Out:
#  34567890

# %%
type(a)
# Out:
# str

# %%
b = 45

# %%
a + b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 a + b
#
# TypeError: can only concatenate str (not "int") to str

# %%
int(a) + b
# Out:
# 34567935

# %%
int('2345')
# Out:
# 2345

# %%
str(45567947)
# Out:
# '45567947'

# %% [markdown]
#      ################# LEC -02 ####################################

# %%
s = "Kanha"
type(s)
# Out:
# str

# %%
s[0]
# Out:
# 'K'

# %%
s[1]
# Out:
# 'a'

# %%
s[2]
# Out:
# 'n'

# %%
s[3]
# Out:
# 'h'

# %%
s[4]
# Out:
# 'a'

# %%
s[-1]
# Out:
# 'a'

# %%
s[-2]
# Out:
# 'h'

# %%
a = "my name is kanh"

# %%
a[-1]
# Out:
# 'h'

# %%
a[0]
# Out:
# 'm'

# %%
a[100]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 a[100]
#
# IndexError: string index out of range

# %%
a
# Out:
# 'my name is kanh'

# %%
a[0:10]
# Out:
# 'my name is'

# %%
b = "ineuron"

# %%
b[0:3]
# Out:
# 'ine'

# %%
b[0:300]
# Out:
# 'ineuron'

# %%
b[300]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 b[300]
#
# IndexError: string index out of range

# %%
b[-1]
# Out:
# 'n'

# %%
b[-100]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 b[-100]
#
# IndexError: string index out of range

# %%
b[-1:-4]
# Out:
# ''

# %%
b[0:4]
# Out:
# 'ineu'

# %%
a = "kumar"

# %%
a[0:300:1]
# Out:
# 'kumar'

# %%
a[0:300:2]
# Out:
# 'kmr'

# %%
a[0:300:3]
# Out:
# 'ka'

# %%
a[0:300:4]
# Out:
# 'kr'

# %%
a[0:100:-1]
# Out:
# ''

# %%
a[0:300:1]
# Out:
# 'kumar'

# %%
a[-1:-4]
# Out:
# ''

# %%
a[-1:-4:-1]
# Out:
# 'ram'

# %%
a[0:-10:-1]
# Out:
# 'k'

# %%
a
# Out:
# 'kumar'

# %%
a[::]
# Out:
# 'kumar'

# %%
a[:8]
# Out:
# 'kumar'

# %%
a[-2:]
# Out:
# 'ar'

# %%
a[-2:-1]
# Out:
# 'a'

# %%
a[::-1]
# Out:
# 'ramuk'

# %%
a[-1::-1]
# Out:
# 'ramuk'

# %%
a = "i am working with Ineuron"
a[::-1]
# Out:
# 'noruenI htiw gnikrow ma i'

# %%
a[-5:5:]
# Out:
# ''

# %%
a[-5:5:-1]
# Out:
# 'enI htiw gnikro'

# %%
a[-5:5:1]
# Out:
# ''

# %%
a[-2 :-10:-1]
# Out:
# 'oruenI h'

# %%
a[0:100:3]
# Out:
# 'imoi tIun'

# %%
"sudh"*3
# Out:
# 'sudhsudhsudh'

# %%
"kanha" + " kumar"
# Out:
# 'kanha kumar'

# %%
a
# Out:
# 'i am working with Ineuron'

# %%
len(a)
# Out:
# 25

# %%
3*"sudh"
# Out:
# 'sudhsudhsudh'

# %%
"sudh"*"sudh"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 "sudh"*"sudh"
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
a
# Out:
# 'i am working with Ineuron'

# %%
"kanha"+"sudh"
# Out:
# 'kanhasudh'

# %%
a
# Out:
# 'i am working with Ineuron'

# %%
a.find('a')
# Out:
# 2

# %%
a.find('i')
# Out:
# 0

# %%
a.find('ia')
# Out:
# -1

# %%
a.find('in')
# Out:
# 9

# %%
a.count('i')
# Out:
# 3

# %%
a = 'i am working with ineuron'

# %%
a.count('i')
# Out:
# 4

# %%
a.count('x')
# Out:
# 0

# %%
a
# Out:
# 'i am working with ineuron'

# %%
a.split()
# Out:
# ['i', 'am', 'working', 'with', 'ineuron']

# %%
type(a.split())
# Out:
# list

# %%
 l =a.split()

# %%
l
# Out:
# ['i', 'am', 'working', 'with', 'ineuron']

# %%
l[0]
# Out:
# 'i'

# %%
l[1]
# Out:
# 'am'

# %%
l[2]
# Out:
# 'working'

# %%
l[0:3]
# Out:
# ['i', 'am', 'working']

# %%
a.split("w")
# Out:
# ['i am ', 'orking ', 'ith ineuron']

# %%
a
# Out:
# 'i am working with ineuron'

# %%
a
# Out:
# 'i am working with ineuron'

# %%
a.split("wo")
# Out:
# ['i am ', 'rking with ineuron']

# %%
a
# Out:
# 'i am working with ineuron'

# %%
a.upper()
# Out:
# 'I AM WORKING WITH INEURON'

# %%
a.lower()
# Out:
# 'i am working with ineuron'

# %%
s = "SUdh"

# %%
s.swapcase()
# Out:
# 'suDH'

# %%
s.title()
# Out:
# 'Sudh'

# %%
s.capitalize()
# Out:
# 'Sudh'

# %%
b = "kanha"
c = "aiya"

# %%
b.join(c)
# Out:
# 'akanhaikanhaykanhaa'

# %%
" " .join("kanha")
# Out:
# 'k a n h a'

# %%
reversed("kanha")

# %%
for i in reversed("kanha"):
    print(i)
# Out:
# a
# h
# n
# a
# k

# %%
s ="kanha"
s[::-1]
# Out:
# 'ahnak'

# %%
s = " sudh "

# %%
s.rstrip()
# Out:
# ' sudh'

# %%
s.lstrip()
# Out:
# 'sudh '

# %%
s.strip()
# Out:
# 'sudh'

# %%
s = "sudh"

# %%
s.replace("u" , "xyz")
# Out:
# 'sxyzdh'

# %%
s.replace("t" , "xyz")
# Out:
# 'sudh'

# %%
"sudh\tkumar".expandtabs()
# Out:
# 'sudh    kumar'

# %%
s= "sudh"

# %%
s.center(40 , "t")
# Out:
# 'ttttttttttttttttttsudhtttttttttttttttttt'

# %%
s.center(40 , "tnet")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[119], line 1
# ----> 1 s.center(40 , "tnet")
#
# TypeError: The fill character must be exactly one character long

# %%
s.center(40 , "p")
# Out:
# 'ppppppppppppppppppsudhpppppppppppppppppp'

# %%
b="          indians are the best in the world"
b.strip("are")
# Out:
# '          indians are the best in the world'

# %%
b="          indians are the best in the world"
b.strip()
# Out:
# 'indians are the best in the world'

# %%
s ="sudh"

# %%
s.isupper()
# Out:
# False

# %%
s ="Sudh"

# %%
s.isupper()
# Out:
# False

# %%
s ="SUDH"
s.isupper()
# Out:
# True

# %%
s.islower()
# Out:
# False

# %%
s.isspace()
# Out:
# False

# %%
s ="                    sudh"
s.isspace()
# Out:
# False

# %%
s ="              "
s.isspace()
# Out:
# True

# %%
s.isdigit()
# Out:
# False

# %%
s ="12345"
s.isdigit()
# Out:
# True

# %%
s ="sudh"
s.endswith("h")
# Out:
# True

# %%
s.endswith("x")
# Out:
# False

# %%
s.startswith("t")
# Out:
# False

# %%
s.startswith("s")
# Out:
# True

# %%
s.istitle()
# Out:
# False

# %%
s ="Sudh"
s.istitle()
# Out:
# True

# %%
s.encode()
# Out:
# b'Sudh'

# %%
s.encode("jis kanhaiya")
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 s.encode("jis kanhaiya")
#
# LookupError: unknown encoding: jis kanhaiya

# %% [markdown]
# ###############List

# %%
s = "jsskf lsdsld lsdkslk sofs"

# %%
l = ["sudh" , "KUmar" , 3456 , 4+6j  , True , 345.56]

# %%
type(l)
# Out:
# list

# %%
l[0]
# Out:
# 'sudh'

# %%
l[-1]
# Out:
# 345.56

# %%
l[-5]
# Out:
# 'KUmar'

# %%
l[0:4]
# Out:
# ['sudh', 'KUmar', 3456, (4+6j)]

# %%
l[::-1]
# Out:
# [345.56, True, (4+6j), 3456, 'KUmar', 'sudh']

# %%
l[-1:6]
# Out:
# [345.56]

# %%
l[0]
# Out:
# 'sudh'

# %%
type(l[0])
# Out:
# str

# %%
type(l[4])
# Out:
# bool

# %%
l[0][1]
# Out:
# 'u'

# %%
l[3]
# Out:
# (4+6j)

# %%
l[3].real
# Out:
# 4.0

# %%
l[3].imag
# Out:
# 6.0

# %%
l1 = ["sudh" , "kumar" , 4567]
l2 = ["xyz" , "lkr"  , 56.77]

# %%
l1+l2
# Out:
# ['sudh', 'kumar', 4567, 'xyz', 'lkr', 56.77]

# %%
l1-l2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 l1-l2
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'

# %%
l1 + "kanha"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 l1 + "kanha"
#
# TypeError: can only concatenate list (not "str") to list

# %%
l1 + ["kanha"]
# Out:
# ['sudh', 'kumar', 4567, 'kanha']

# %%
l1*5
# Out:
# ['sudh',
#  'kumar',
#  4567,
#  'sudh',
#  'kumar',
#  4567,
#  'sudh',
#  'kumar',
#  4567,
#  'sudh',
#  'kumar',
#  4567,
#  'sudh',
#  'kumar',
#  4567]

# %%
l1*2
# Out:
# ['sudh', 'kumar', 4567, 'sudh', 'kumar', 4567]

# %%
l1[0] ="kanha"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 l1[0] ="kanha"
#
# TypeError: 'bool' object does not support item assignment

# %%
l1
# Out:
# False

# %%
l1 = ["sudh" , "kumar" , 4567]
l2 = ["xyz" , "lkr"  , 56.77]

# %%
l1[0] ="kanha"

# %%
l1
# Out:
# ['kanha', 'kumar', 4567]

# %%
l1[0] ="skdjdkg"

# %%
l1
# Out:
# ['skdjdkg', 'kumar', 4567]

# %%
l[1][0]
# Out:
# 'K'

# %%
s ="kanha"

# %%
s[0] = "s"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 s[0] = "s"
#
# TypeError: 'str' object does not support item assignment

# %%
l[1] = "sudh"

# %%
s.replace('k' , 'v')
# Out:
# 'vanha'

# %%
s
# Out:
# 'kanha'

# %%
s[0] = 'v'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 s[0] = 'v'
#
# TypeError: 'str' object does not support item assignment

# %%
len(l1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 len(l1)
#
# NameError: name 'l1' is not defined

# %%
# Out:
#   Cell In[2], line 1
#     https://youtu.be/rDW2U9xNmxo
#           ^
# SyntaxError: invalid syntax

# %%
l1 = ["sudh" , "kumar" , 4567]
l2 = ["xyz" , "lkr"  , 56.77]

# %%
l1
# Out:
# ['sudh', 'kumar', 4567]

# %%
len(l1)
# Out:
# 3

# %%
"kumar" in l1
# Out:
# True

# %%
345 in l1
# Out:
# False

# %%
l = ['okau' , 'kumar' ,567, 6.6 ,"True" , 6+8j]
l[-1:6:-1]
# Out:
# []

# %%
l2
# Out:
# ['xyz', 'lkr', 56.77]

# %%
l2.append("sudh")

# %%
l2.pop()
# Out:
# 'sudh'

# %%
l2
# Out:
# ['xyz', 'lkr', 56.77]

# %%
l2.pop(3)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 l2.pop(3)
#
# IndexError: pop index out of range

# %%
l2.pop(2)
# Out:
# 56.77

# %%
l2
# Out:
# ['xyz', 'lkr']

# %%
l2
# Out:
# ['xyz', 'lkr']

# %%
l2.append(346667)

# %%
l2
# Out:
# ['xyz', 'lkr', 346667]

# %%
l2.insert(1, 'sff')

# %%
l2
# Out:
# ['xyz', 'sff', 'lkr', 346667]

# %%
l2.insert(3, [234,56,78.09])

# %%
l2
# Out:
# ['xyz', 'sff', 'lkr', [234, 56, 78.09], 346667]

# %%
l2[::-1]
# Out:
# [346667, [234, 56, 78.09], 'lkr', 'sff', 'xyz']

# %%
l2.reverse()

# %%
l2
# Out:
# [346667, [234, 56, 78.09], 'lkr', 'sff', 'xyz']

# %%
l2
# Out:
# [346667, [234, 56, 78.09], 'lkr', 'sff', 'xyz']

# %%
l1
# Out:
# ['sudh', 'kumar', 4567]

# %%
l2
# Out:
# [346667, [234, 56, 78.09], 'lkr', 'sff', 'xyz']

# %%
l2[1][1]
# Out:
# 56

# %%
l2.count()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 l2.count()
#
# TypeError: list.count() takes exactly one argument (0 given)

# %%
l2.count('xyz')
# Out:
# 1

# %%
l2.count('lp')
# Out:
# 0

# %%
l2.append([3,4,5,6])

# %%
l2
# Out:
# [346667, [234, 56, 78.09], 'lkr', 'sff', 'xyz', [3, 4, 5, 6]]

# %%
l2.append("kanhaiya lal Dotaniya")

# %%
l2
# Out:
# [346667,
#  [234, 56, 78.09],
#  'lkr',
#  'sff',
#  'xyz',
#  [3, 4, 5, 6],
#  'kanhaiya lal Dotaniya']

# %%
l1
# Out:
# ['sudh', 'kumar', 4567]

# %%
l1.extend([2,54,678,728,"sdf"])

# %%
l1
# Out:
# ['sudh', 'kumar', 4567, 2, 54, 678, 728, 2, 54, 678, 728, 'sdf']

# %%
l1.extend([[2,54,678,728,"sdf"]])

# %%
l1
# Out:
# ['sudh',
#  'kumar',
#  4567,
#  2,
#  54,
#  678,
#  728,
#  2,
#  54,
#  678,
#  728,
#  'sdf',
#  [2, 54, 678, 728, 'sdf']]

# %%
print(l2.reverse())
# Out:
# None

# %%
l1=[24,567]
l1+list('sudh')
l1+['sudh']
# Out:
# [24, 567, 'sudh']

# %%
list("sudh")
# Out:
# ['s', 'u', 'd', 'h']

# %%
s = 'kanha'
s.endswith("")
# Out:
# True

# %%
s = 456
s.endswith("")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[52], line 2
#       1 s = 456
# ----> 2 s.endswith("")
#
# AttributeError: 'int' object has no attribute 'endswith'

# %%
s
# Out:
# 456

# %%
s =    "sudh    "
s.endswith("")
# Out:
# True

# %%
l = ["sudh" ,345,42445,900987]

# %%
l.append("kumar")

# %%
l
# Out:
# ['sudh', 345, 42445, 900987, 'kumar']

# %%
l.extend(345)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 l.extend(345)
#
# TypeError: 'int' object is not iterable

# %%
l
# Out:
# ['sudh', 345, 42445, 900987, 'kumar']

# %%
l.append([23,45,78,9])

# %%
l
# Out:
# ['sudh', 345, 42445, 900987, 'kumar', [23, 45, 78, 9]]

# %%
l.extend()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 l.extend()
#
# TypeError: list.extend() takes exactly one argument (0 given)

# %%
l.extend([2,4,5,6,7,87,8])

# %%
l
# Out:
# ['sudh', 345, 42445, 900987, 'kumar', [23, 45, 78, 9], 2, 4, 5, 6, 7, 87, 8]

# %%
[2,3,4,5,6,7,0] +[4,5,6,7,]
# Out:
# [2, 3, 4, 5, 6, 7, 0, 4, 5, 6, 7]

# %%
"kajanndksdosdksd la lal lkakk aks lal ".split('#')
# Out:
# ['kajanndksdosdksd la lal lkakk aks lal ']

# %%
l =["sudh" , "kumar" ,4567,5+7j ,True,345.7]
l[-1:6]
# Out:
# [345.7]

# %%
"sjdjdjfjjff\tsadfa\tknkscsff\t".expandtabs()
# Out:
# 'sjdjdjfjjff     sadfa   knkscsff        '

# %% [markdown]
# //////Touples class already notes are occur in diffrent file so you can check this +++++++++++++++
