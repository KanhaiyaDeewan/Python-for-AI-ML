# %%
#take two number from user and print the greater one#
a = int(input('Enter the first value'))
b = int(input('Enter the second value'))
if a>b:
    print("The gratest value of a " , a)
if b>a :
    print("the greatest value of b" , b)
# Out:
# Enter the first value 25
# Enter the second value 45
# the greatest value of b 45

# %%
"""enter the value from the user, and check the number is true or false"""
a = int(input('enter the value'))
if a%2 ==0:
        print(" number enter by the user is even number")
if a%2!=0 :
        print(" number enter by the user is not even number")
# Out:
# enter the value 13
#  number enter by the user is not even number

# %%
a = input("Tossed a coin")
if a =="head":
            print("team a will be bat first")
if a =="tail":
            print("team b will be bat first")
# Out:
# Tossed a coin tail
# team b will be bat first

# %%
y = int(input('enter a number'))
if y%13==0:
        print("the no.is divisible by 13")
if y%13!=0:
        print("the no.is  not divisible by 13")
# Out:
# enter a number 142
# the no.is  not divisible by 13

# %%
z = input("enter the color of the ball")
if z == "blue":
    print("raju will be play in team blue")
if z == "green":
    print("raju will be play in team green")
print("raju will not play")
# Out:
# enter the color of the ball green
# raju will be play in team green
# raju will not play

# %% [markdown]
# **if else condition**

# %%
a = int(input("enter the value"))
if a >20:
    print("magic")
else:
    print("no magic")
# Out:
# enter the value 34
# magic

# %%
p = int(input("please enter your age"))
if p >=60:
    print("senior citizen")
else:
    print("not a senior citizen ")
# Out:
# please enter your age 40
# not a senior citizen

# %%
a = int(input("enter your age"))
if a>=18:
    print("you are elligible for voting")
else:
    print("you are not elligible for voting")
print("ellection is coming soon")
# Out:
# enter your age 33
# you are elligible for voting
# ellection is coming soon

# %% [markdown]
# **if elif else statement**

# %%
a = int(input("enter the first value please"))
b = int(input("enter the second value please"))
if a >b:
    print("the value is greater")
elif a==b:
    print("value are equal")
else :
    print("value is not equal")
# Out:
# enter the first value please 67
# enter the second value please 67
# value are equal

# %%
a = int(input("enter the first value please"))
if a%2==0:
    print("number is divisible by 2")
elif a%3==0:
    print("number is divisible by 3")
else :
    print("number is not divisible by 2 and 3")
# Out:
# enter the first value please 13
# number is not divisible by 2 and 3

# %%
x =int(input("please enter the marks"))
if x>85:
       print("A grade")
elif x>=85:
        print("B grade")
elif x>=75 and x<85:
        print("c grade")
elif x>=75 and x<75:
        print("D grade")
elif x>=65 and x<70:
        print(" E grade")
else :
        print("fail")
# Out:
# please enter the marks 76
# c grade

# %%
x =int(input(" enter the value"))
if a==1:
       print("Monday")
elif a==2:
        print("tuesday")
elif a==3:
        print("wednesday")
elif a==4:
        print("Thrusday")
elif a==5:
        print(" friday")

elif a==6:
        print(" saturday")

elif a==7:
        print(" sunday")
else :
        print("no day")
# Out:
#  enter the value 1452
# no day

# %%
a =12
if a>13:
    print("yellow")
else:
    print("orange")
# Out:
# orange

# %% [markdown]
# **nested if statement**

# %%
a = int(input("enter the value please"))
if a>10:
    print("Inside the if condition")
    if a>20:
        print("inside the nested if")
    else:
        print("inside the else part of nested if")
else:
    print("outside the condition")
# Out:
# enter the value please 5
# outside the condition

# %%
a =int(input("enter the number of classes attended by student"))
b =int(input("enter the number of assignment submit by student"))
if a>75:
    print("Elligible for exam one")
    if b>10:
       print("eligible for exam one and two")
    else :
       print("Elligible for exam one but not elligible for exam two")
else:
    print("you are suspended")
# Out:
# enter the number of classes attended by student 50
# enter the number of assignment submit by student 0
# you are suspended
