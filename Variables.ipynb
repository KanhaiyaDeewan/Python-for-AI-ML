# %%
a =4.2456
round(a)
# Out:
# 4

# %%
a = 12.6
print(round(a))
# Out:
# 13

# %%
a = 15.56789
round(a,3)
# Out:
# 15.568

# %%
round(a,4)
# Out:
# 15.5679

# %%
print(round(1478.789028345 , 5))
# Out:
# 1478.78903

# %%
"""Mohan buys 3 Tablets cost of 1 tablet 1 is rs.45.67, cost of tablet 2 in 68.97 etc."""

tablet_one = 45.67
tablet_two = 68.987
tablet_three = 574.897
print(round(tablet_one+tablet_two+tablet_three))
# Out:
# 690

# %%
round(789.1456, 2 )
# Out:
# 789.15

# %% [markdown]
# **Div mod**

# %%
a = divmod(25 , 7)

# %%
print(a)
# Out:
# (3, 4)

# %%
type(a)
# Out:
# tuple

# %%
a[0]
print(a[0])
# Out:
# 3

# %%
a[1]
print(a[1])
# Out:
# 4

# %%
25//7
# Out:
# 3

# %%
25%7
# Out:
# 4

# %%
a = divmod(123.456,3)
print(a)
# Out:
# (41.0, 0.45600000000000307)

# %%
print(divmod(123456789, 45125))
# Out:
# (2735, 39914)

# %%
"""divide the number 148.789 by 12,13,14 and 15 seperately,and their quotient"""
a = divmod(148.789,12)
b = divmod(148.789,13)
c = divmod(148.789,14)
d = divmod(148.789,15)
print(a,b,c,d)
# Out:
# (12.0, 4.788999999999987) (11.0, 5.788999999999987) (10.0, 8.788999999999987) (9.0, 13.788999999999987)

# %%
q = a[0]+b[0]+c[0]+d[0]
print("sum of quotients are:" , q)
r = a[1]+b[1]+c[1]+d[1]
print("sum of quotients are:" , r)
# Out:
# sum of quotients are: 42.0
# sum of quotients are: 33.15599999999995

# %%
round(r)
# Out:
# 33

# %% [markdown]
# **isinstance funtion**

# %%
isinstance(3,int)
# Out:
# True

# %%
isinstance(3.0,int)
# Out:
# False

# %%
isinstance(3.0,(int,float))
# Out:
# True

# %%
print(isinstance("python is amazing",(int,float,str)))
# Out:
# True

# %%
2+3j
# Out:
# (2+3j)

# %%
isinstance(2+3j, (int, float, complex ))
# Out:
# True

# %%
isinstance( 3.45, (int, complex ))
# Out:
# False

# %%
isinstance(3.78, (int,float, complex))
# Out:
# True

# %% [markdown]
# **pow function**

# %%
pow(2,4)
# Out:
# 16

# %%
2**4
# Out:
# 16

# %%
pow(45, 78)
# Out:
# 892433931724899592133340503925107044376202040970794580884598711678709679913526717581436810411421589606106863357126712799072265625

# %%
pow( 3.2, 4)
# Out:
# 104.85760000000002

# %%
pow(2+3j , 2)
# Out:
# (-5+12j)

# %%
(2+3j)**2
# Out:
# (-5+12j)

# %%
pow(2,4,7)
# Out:
# 2

# %%
pow(3,4,5)
# Out:
# 1

# %%
""" 24 raise to the power 2,3,4,5 and divide it by 7 find the remainder in each"""
a =pow(24,2,7)
b =pow(24,3,7)
c =pow(24,4,7)
d= pow(24,5,7)
print(a,b,c,d)
# Out:
# 2 6 4 5

# %%
a = pow(63,45,52)
print(a)
# Out:
# 47

# %% [markdown]
# **Input function , int function and float and float function**

# %%
x =input("Enter the value")
# Out:
# Enter the value 45

# %%
print(x)
# Out:
# 45

# %%
print(type(x))
# Out:
# <class 'str'>

# %%
x = int(x)

# %%
print(x)
print(type(x))
# Out:
# 45
# <class 'int'>

# %%
print(x-21)
print(x+21)
# Out:
# 24
# 66

# %%
a = input("hello user, please enter your value ")
# Out:
# hello user, please enter your value  5.2

# %%
print(a)
print(type(a))
# Out:
# 5.2
# <class 'str'>

# %%
a = float(a)

# %%
print(a)
print(type(a))
# Out:
# 5.2
# <class 'float'>

# %%
a = float(a)

# %%
print(a)
print(type(a))
# Out:
# 5.2
# <class 'float'>

# %%
print(a-1.2)
print(a*2)
# Out:
# 4.0
# 10.4

# %%
### """ lets make a result of the student , ask the user to enter the marks of eng,"""
a = input("Enter the marks of maths")
b = input("Enter the marks of science")
c = input("Enter the marks of social")
d = input("Enter the marks of English")
e = input("Enter the marks of Hindi")
# Out:
# Enter the marks of maths 45
# Enter the marks of science 56
# Enter the marks of social 33
# Enter the marks of English 45
# Enter the marks of Hindi 90

# %%
a = int(a)
b = int(b)
c = int(c)
d = int(d)
e = int(e)
print(a+b+c+d+e)
# Out:
# 269

# %%
print((395/500)*100)
# Out:
# 79.0

# %% [markdown]
# **Len Function**

# %%
a = "I am learning python"
print(a)
# Out:
# I am learning python

# %%
print(len(a))
# Out:
# 20

# %%
x = "python is high programing language "
y = "and it is easy to learn "
print(x+y)
# Out:
# python is high programing language and it is easy to learn

# %%
print(len(x+y))
# Out:
# 59

# %%
L = [12,17,45,96,78,98,44,56]
len(L)
# Out:
# 8

# %%
A = 1234.678989712
len(A)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[75], line 2
#       1 A = 1234.678989712
# ----> 2 len(A)
#
# TypeError: object of type 'float' has no len()

# %% [markdown]
# **min and max function**

# %%
L = [12,45,-78, -90, -23 , 788 ,90]
min(L)
# Out:
# -90

# %%
max(L)
# Out:
# 788

# %%
a = input("Enter the 1st value")
b = input("Enter the 2nd value")
c = input("Enter the 3rd value")
d = input("Enter the 4th value")
e = input("Enter the 5th value")
# Out:
# Enter the 1st value 34
# Enter the 2nd value 12.5
# Enter the 3rd value -4
# Enter the 4th value 51
# Enter the 5th value -47

# %%
a = int(a)
b = float(b)
c = int(c)
d = int(d)
e = int(e)
print("values given by user" , a,b,c,d,e)
print("The minimum value is" , min(a,b,c,e,d))
print("the maximum value is" , max(a,b,c,d,e))
# Out:
# values given by user 34 12.5 -4 51 -47
# The minimum value is -47
# the maximum value is 51

# %% [markdown]
# **Sorted function**

# %%
L = [12,74,23,-9,-45,58,96,0,5,63]
sorted(L)
# Out:
# [-45, -9, 0, 5, 12, 23, 58, 63, 74, 96]

# %%
sorted(L,  reverse = True)
# Out:
# [96, 74, 63, 58, 23, 12, 5, 0, -9, -45]

# %%
a = input("Enter the 1st value")
b = input("Enter the 2nd value")
c = input("Enter the 3rd value")
d = input("Enter the 4th value")
e = input("Enter the 5th value")
# Out:
# Enter the 1st value 124
# Enter the 2nd value 12.56
# Enter the 3rd value -5
# Enter the 4th value 26
# Enter the 5th value -94

# %%
a = int(a)
b = float(b)
c = int(c)
d = int(d)
e = int(e)
print(a,b,c,d,e)
# Out:
# 124 12.56 -5 26 -94

# %%
x =(a,b,c,d,e)
print(sorted(x))
# Out:
# [-94, -5, 12.56, 26, 124]

# %%
print(sorted(x, reverse = True))
# Out:
# [124, 26, 12.56, -5, -94]

# %% [markdown]
# **How to use any function in Python**

# %%
pow?
# Out:
# Signature: pow(base, exp, mod=None)
# Docstring:
# Equivalent to base**exp with 2 arguments or base**exp % mod with 3 arguments
#
# Some types, such as ints, are able to use a more efficient algorithm when
# invoked using the three argument form.
# Type:      builtin_function_or_method

# %%
help(divmod)
# Out:
# Help on built-in function divmod in module builtins:
#
# divmod(x, y, /)
#     Return the tuple (x//y, x%y).  Invariant: div*y + mod == x.

# %%
divmod?
# Out:
# Signature: divmod(x, y, /)
# Docstring: Return the tuple (x//y, x%y).  Invariant: div*y + mod == x.
# Type:      builtin_function_or_method

# %%
divmod??
# Out:
# Signature: divmod(x, y, /)
# Docstring: Return the tuple (x//y, x%y).  Invariant: div*y + mod == x.
# Type:      builtin_function_or_method

# %%
max??
# Out:
# Docstring:
# max(iterable, *[, default=obj, key=func]) -> value
# max(arg1, arg2, *args, *[, key=func]) -> value
#
# With a single iterable argument, return its biggest item. The
# default keyword-only argument specifies an object to return if
# the provided iterable is empty.
# With two or more arguments, return the largest argument.
# Type:      builtin_function_or_method
