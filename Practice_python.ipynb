# %%
print('Hello , World!')
print("python" , "is" , "fun!")
#Python-is-fun!
print("Python" , "is" ,"fun!" , sep ='@')
print("Learning" , end ="\n" )
print("python!")
# Out:
# Hello , World!
# python is fun!
# Python@is@fun!
# Learning
# python!

# %%
print("Learning" , end =" " )
print("python!")
# Out:
# Learning python!

# %%
print("*")
print("**")
print("***")
print("****")
print("******")
# Out:
# *
# **
# ***
# ****
# ******

# %%
print("  *")
print(" **")
print("***")
# Out:
#   *
#  **
# ***

# %%
#Diffrent types of NUmber 20 30.33
print("Diffrent types of Numbers" , 20 , 30.33)
# Out:
# Diffrent types of Numbers 20 30.33

# %%
print("Hello")
# Out:
# Hello

# %%
Print("Hello")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 Print("Hello")
#
# NameError: name 'Print' is not defined

# %%
# smiling face with smiling eyes
print('\N{smiling face with smiling eyes}')
# Out:
# 😊

# %%
# Grinning face
print('\N{grinning face}')
# Out:
# 😀

# %%
print('\N{smiling face with halo}')
# Out:
# 😇

# %%
print('\N{thinking face}')
# Out:
# 🤔

# %%
## this is a single line comment
print("hello") # this is example of print function
# Out:
# hello

# %%
#Triple quotes
'''
    this is multiple line comment
    second line
      '''
print("Hello")
# Out:
# Hello

# %%
age = 32
if age>30:
    print(age)  #idention
print(age)
# Out:
# 32
# 32

# %%
age=32
if age>30:
    print(age)
# Out:
# 32

# %%
#line cohtituation
##use a backlash(\)to continue a statement to the next line
total = 1+2+3+4+\
5+6+7
print(total)
# Out:
# 28

# %%
a= 20
print(type(a))
# Out:
# <class 'int'>

# %%
variable="python"
print(type(variable))
# Out:
# <class 'str'>

# %%
r =int(input("Enter the radius of the circle:"))
area = 3.14*r*r
print("Area of the circle with radius" , r, "is" , area)
# Out:
# Enter the radius of the circle: 16
# Area of the circle with radius 16 is 803.84

# %%
## Declaring and assignment variables

##rohit- 23 -5.9 -student

name="Rohit"
age = 23
height=5.9
is_student=True
#print variable

print("age: ",age)
print("Height: ",height)
print("Name: ",name)
# Out:
# age:  23
# Height:  5.9
# Name:  Rohit

# %%
##Invalid variables name
#2age = 30
#first-name="rohit"
#@name = "raj"
# Out:
#   Cell In[31], line 3
#     first-name="rohit"
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
# case sensitive
name="Rohit"
Name="Mohit"

print(name)
# Out:
# Rohit

# %%
## understanding variale types
age = 25 #int
height=6.1 #float
name = "Robin" #str
is_student=True #bool

print(type(age))
# Out:
# <class 'int'>

# %%
print(type(is_student))
# Out:
# <class 'bool'>

# %%
#python is dynamicaly types. Types of a varible to detrmined at runtime
b =2
print(type(b))
b =3.4
print(type(b))
b =True
print(type(b))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
name =input("what is y0ur name")
# Out:
# what is y0ur name Rohit

# %%
print(name)
# Out:
# Rohit

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
name='raj'
First_name = "sohan"
print(type(name))
(print(type(First_name)))
# Out:
# <class 'str'>
# <class 'str'>

# %%
x=12 #int
y=12.33 #float
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'float'>

# %%
is_student=False
print(type(is_student))
# Out:
# <class 'bool'>

# %%
mylist = [2,3,4, 'yes', 'No']
print(mylist)
# Out:
# [2, 3, 4, 'yes', 'No']

# %%
list1=[10,20,30,40,50.55 , 'yes']
print(list1[5])
print(type(list1[5]))
print(type(list1))
# Out:
# yes
# <class 'str'>
# <class 'list'>

# %% [markdown]
# #

# %%
age = 25
print(type(age))

#type conversion
age_str=str(age)
print(age_str)
type(age_str)
# Out:
# <class 'int'>
# 25
# str

# %%
age_str="25"
print(type(age_str))
age_int=int(age_str)
print(type(age_int))
# Out:
# <class 'str'>
# <class 'int'>

# %%
name ="rohit"
int(name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 2
#       1 name ="rohit"
# ----> 2 int(name)
#
# ValueError: invalid literal for int() with base 10: 'rohit'

# %%
name = 30
str(name)
# Out:
# '30'

# %%
height = 5.12
type(height)
# Out:
# float

# %%
#float to int
int(height)
# Out:
# 5

# %%
#int to float
float(int(height))
# Out:
# 5.0

# %%
#convert int to bool
a=bool(10)
b=bool(0)
c=bool(-10)

print(a , type(a))
print(b , type(b))
print(c , type(c))
# Out:
# True <class 'bool'>
# False <class 'bool'>
# True <class 'bool'>

# %%
#covert str to bool
a=bool("india")
b=bool("100")
c=bool("0")
d=bool("")
print(a , type(a))
print(b , type(b))
print(c , type(c))
print(d , type(d))
# Out:
# True <class 'bool'>
# True <class 'bool'>
# True <class 'bool'>
# False <class 'bool'>

# %%
#float to bool
a=bool(10.4)
b=bool(0.0)
c=bool(-10.8)
print(a , type(a))
print(b , type(b))
print(c , type(c))
# Out:
# True <class 'bool'>
# False <class 'bool'>
# True <class 'bool'>

# %%
#addition operator
x=20
y=30
result=x+y
print(result)
# Out:
# 50

# %%
x="ello"
y="world"
result=x+y
print(result)
# Out:
# elloworld

# %%
#subtraction
x=34
y=12
print(x-y)
# Out:
# 22

# %%
#multiplication
x=10
y=89
print(x*y)
# Out:
# 890

# %%
x=10
y=6
result=(x/y)
print(result)
# Out:
# 1.6666666666666667

# %%
#exponential
x=2
y=3
result=x**y
print(result)
# Out:
# 8

# %%
x=5 %2
print(x)
# Out:
# 1

# %%
print( 17//5 )
# Out:
# 3

# %%
#equallity operator
x=5
y=5
print(x==y)
# Out:
# True

# %%
x=5
y=6
print(x==y)
# Out:
# False

# %%
name="python"
name1="java"
print(name==name1)
# Out:
# False

# %%
n=True
m=False
print(n==m)
# Out:
# False

# %%
#inequality
x=5
y=5
print(x!=y)
# Out:
# False

# %%
#Greater than
print(8>5)
# Out:
# True

# %%
print(5>8)
# Out:
# False

# %%
#less than
print(9<67)
# Out:
# True

# %%
#Greater than equal to
print(8 >=4)
# Out:
# True

# %%
print(2 >=4)
# Out:
# False

# %%
#less than equal to
print(10 <= 15)
# Out:
# True

# %%
print(15 <= 15)
# Out:
# True

# %%
#logical and
print(True and True)
print(True and False)
print(False and False)
# Out:
# True
# False
# False

# %%
#OR
print(True or True)
print(True or False)
print(False or False)
# Out:
# True
# True
# False

# %%
#Not
print(not(True))
print(not( False))
# Out:
# False
# True

# %%
x =10+3*5
print(x)
# Out:
# 25

# %%
#output 65
x=(10+3)*5
print(x)
# Out:
# 65

# %%
x =2**3*2 ,print(x) ###
# Out:
# 65

# %%
x=45/15//2
print(x)
# Out:
# 1.0

# %%
not True and True
# Out:
# False

# %%
x ='good'
print(len(x))
# Out:
# 4

# %%
string1 = 'first'
string2 =','
string3='second'
string4=string1+string2+string3
print(string4)
# Out:
# first,second

# %%
s ='good'
five_s=s*5
print(five_s)
# Out:
# goodgoodgoodgoodgood

# %%
x = 'python'
y = 'python'
print(x==y)
# Out:
# True

# %%
print ('good' > 'bad')
# Out:
# True

# %%
print('nine' < 'one')# seq n ko compare o
# Out:
# True

# %%
print('a' < 'ab' < 'abc' < 'b')
# Out:
# True

# %%
print(ord('a'))
print(ord('b'))
print(ord('A'))
# Out:
# 97
# 98
# 65

# %%
#This is the first sentence
##this is second charzcter
print('This is the first sentence.\nThis is the second sentence.')
# Out:
# This is the first sentence.
# This is the second sentence.

# %%
print('a\tb')
# Out:
# a	b

# %%
print('India\'s captial is New Delhi')
# Out:
# India's captial is New Delhi

# %%
#substring
a = 'good'
b= 'very good'
present = a in b
print(present)
not_present= b in a
print(not_present)
# Out:
# True
# False

# %%
#indexing
word='world'
print(word[0])
print(word[4])
# Out:
# w
# d

# %%
print(word[5])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(word[5])
#
# IndexError: string index out of range

# %%
word ='world'
#output d
print(word[-1])
print(word[-2])
# Out:
# d
# l

# %%
#slicing func
email='cs_10_014@iitm.ac.in'
roll=email[6:9]
print(roll)
# Out:
# 014

# %%
branch =email[0:2]
print(branch)
year=email[3:5]
print(year)
college=email[10:14]
print(college)
# Out:
# cs
# 10
# iitm

# %%
#rollno.+branch
email='cs_10_014@iitm.ac.in'
in_roll=email[:9]
print(in_roll)
# Out:
# cs_10_014

# %%
domain=email[-10:]
print(domain)
# Out:
# iitm.ac.in

# %%
word='world' #or output
print(word[-4:3])
print(word[1:3])
print(word[1:-2])
# Out:
# or
# or
# or
