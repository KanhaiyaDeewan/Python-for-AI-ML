# %%
a = 0b1010 #Binary Literals
b = 100 #Decimal Literal 
c = 0o310 #Octal Literal
d = 0x12c #Hexadecimal Literal

#Float Literal
float_1 = 10.5 
float_2 = 1.5e2 # 1.5 * 10^2
float_3 = 1.5e-3 # 1.5 * 10^-3

#Complex Literal 
x = 3.14j

print(a, b, c, d)
print(float_1, float_2,float_3)
print(x, x.imag, x.real)
# Out:
# 10 100 200 300
# 10.5 150.0 0.0015
# 3.14j 3.14 0.0

# %%
print("Hello")
# Out:
# Hello

# %%
print("jkl")
# Out:
# jkl

# %%
a =6
b =7
print(a+b)
print(a*b)
print(a/b)
# Out:
# 13
# 42
# 0.8571428571428571

# %%
l = [1,2,4,5]
print(l)
type(l)
# Out:
# [1, 2, 4, 5]
# list

# %%
print(7)
# Out:
# 7

# %%
print(7.7)
# Out:
# 7.7

# %%
print(True)
# Out:
# True

# %%
print(False)
# Out:
# False

# %%
a = True
b =3.4
c = 9
d = [1,2,3,4]
e = 5+6j
print(a,b,c,d,e ,sep ="/")
# Out:
# True/3.4/9/[1, 2, 3, 4]/(5+6j)

# %% [raw]
# Data Types

# %%
a = 6 #int data types
type(a)

b = 6.345 # float
type(b)
# Out:
# float

# %%
c = True  # bool
type(c)

d = False   # bool
type(d)
# Out:
# bool

# %%
s = 5+6j
print(s) 
type(s)
# Out:
# (5+6j)
# complex

# %%
k = [1,2,3,4,5,9]
print(k)
type(s)
# Out:
# [1, 2, 3, 4, 5, 9]
# complex

# %%
t = (1,2,3,4,5,6,7,0)
type(t)
print(t)
# Out:
# (1, 2, 3, 4, 5, 6, 7, 0)

# %%
print([1,2,3,4,9])
# Out:
# [1, 2, 3, 4, 9]

# %%
l = "Hello world!"
print(l)
type(l)
# Out:
# Hello world!
# str

# %%
_a = "hello"
print(_a)
# Out:
# hello

# %%
s = {3,5,6,78,6}

# %%
type(s)
# Out:
# set

# %%
D = {"name" : 'kanhaiya' , "Age": '23' , "gender": "Male"}

# %%
print(D) 
type(D)
# Out:
# {'name': 'kanhaiya', 'Age': '23', 'gender': 'Male'}
# dict
