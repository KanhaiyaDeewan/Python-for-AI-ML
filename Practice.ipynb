# %% [markdown]
# This is my first program

# %% [markdown]
# Hello Python

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# **Data Types**

# %%
x =3
print(x)
# Out:
# 3

# %%
type(x)
# Out:
# int

# %%
y = 3.456789
type(y)
# Out:
# float

# %%
z = 23 + 67j
type(z)
# Out:
# complex

# %%
print(z)
# Out:
# (23+67j)

# %%
a = "i am learning python "
print(a)
type(a)
# Out:
# i am learning python
# str

# %%
type(a)
# Out:
# str

# %% [markdown]
# **How many Variable are there in text books**

# %%
# %whos
# Out:
# Variable   Type       Data/Info
# -------------------------------
# a          str        i am learning python
# x          int        3
# y          float      3.456789
# z          complex    (23+67j)

# %% [markdown]
# **Deleting varibles from the memory**

# %%
del x

# %%
# %whos
# Out:
# Variable   Type       Data/Info
# -------------------------------
# a          str        i am learning python
# y          float      3.456789
# z          complex    (23+67j)

# %% [markdown]
# **Multiple Assignment**

# %%
a,b,c =12,34.5,"hello"
print(a,b,c)
print(type(a),type(b),type(c))
# Out:
# 12 34.5 hello
# <class 'int'> <class 'float'> <class 'str'>

# %% [markdown]
# **Case Sensitive**

# %%
a = 12
A ="student"
print(a)
# Out:
# 12

# %% [markdown]
# **Python Arthmetic Operators**

# %%
# %whos
# Out:
# Variable   Type       Data/Info
# -------------------------------
# A          str        student
# a          int        12
# b          float      34.5
# c          str        hello
# y          float      3.456789
# z          complex    (23+67j)

# %%
sum = a+y
print(sum)
# Out:
# 15.456789

# %%
print(type(sum))
# Out:
# <class 'float'>

# %%
print(c+A)
# Out:
# hellostudent

# %%
print(c + " " +A)
# Out:
# hello student

# %%
print(z +a)
# Out:
# (35+67j)

# %% [markdown]
# **Subtract  Operator**

# %%
# %whos
# Out:
# Variable   Type       Data/Info
# -------------------------------
# A          str        student
# a          int        12
# b          float      34.5
# c          str        hello
# sum        float      15.456789
# y          float      3.456789
# z          complex    (23+67j)

# %%
print(b-a)
# Out:
# 22.5

# %%
print(z-a)
# Out:
# (11+67j)

# %%
print(sum-y)
# Out:
# 12.0

# %% [markdown]
# **Multiplication operator**

# %%
# %whos
# Out:
# Variable   Type       Data/Info
# -------------------------------
# A          str        student
# a          int        12
# b          float      34.5
# c          str        hello
# sum        float      15.456789
# y          float      3.456789
# z          complex    (23+67j)

# %%
print(a*b)
# Out:
# 414.0

# %%
print(a*z)
# Out:
# (276+804j)

# %%
print(sum * y)
# Out:
# 53.430858190521

# %% [markdown]
# **Division operator**

# %%
# %whos
# Out:
# Variable   Type       Data/Info
# -------------------------------
# A          str        student
# a          int        12
# b          float      34.5
# c          str        hello
# sum        float      15.456789
# y          float      3.456789
# z          complex    (23+67j)

# %%
print(a/b)
# Out:
# 0.34782608695652173

# %%
print(36/12)
# Out:
# 3.0

# %%
print(z/a)
# Out:
# (1.9166666666666667+5.583333333333333j)

# %%
print(sum/y)
# Out:
# 4.471429699643224

# %% [markdown]
# **Modulus Operator**

# %%
n =3

# %%
# %whos
# Out:
# Variable   Type       Data/Info
# -------------------------------
# A          str        student
# a          int        12
# b          float      34.5
# c          str        hello
# n          int        3
# sum        float      15.456789
# y          float      3.456789
# z          complex    (23+67j)

# %%
print(a%n)
# Out:
# 0

# %%
print(a%y)
# Out:
# 1.6296329999999997

# %%
print(14%5)
# Out:
# 4

# %%
print(b%a)
# Out:
# 10.5

# %% [markdown]
# **Exponent Operator**

# %%
# %whos
# Out:
# Variable   Type       Data/Info
# -------------------------------
# A          str        student
# a          int        12
# b          float      34.5
# c          str        hello
# n          int        3
# sum        float      15.456789
# y          float      3.456789
# z          complex    (23+67j)

# %%
print(a**n)
# Out:
# 1728

# %%
print(5**2)
# Out:
# 25

# %%
print(b**n)
# Out:
# 41063.625

# %%
print(z**2)
# Out:
# (-3960+3082j)

# %%
print(3**2 + 5**2)
# Out:
# 34

# %%
print((25**2) + 35 - (24*5) +(99/3))
# Out:
# 573.0

# %% [markdown]
# **Floor Division**

# %%
# %whos
# Out:
# Variable   Type       Data/Info
# -------------------------------
# A          str        student
# a          int        12
# b          float      34.5
# c          str        hello
# n          int        3
# sum        float      15.456789
# y          float      3.456789
# z          complex    (23+67j)

# %%
print(a//n)
# Out:
# 4

# %%
print(sum//a)
# Out:
# 1.0

# %% [markdown]
# **Can a Variable name Start with a digit?**

# %%
12x = 23
# Out:
#   Cell In[59], line 1
#     12x = 23
#      ^
# SyntaxError: invalid decimal literal

# %%
_a = 6

# %%
print(_a)
# Out:
# 6

# %% [markdown]
# **Python assignment operators**

# %%
m = 15

# %%
m+=10

# %%
print(m)
# Out:
# 25

# %%
m-=10

# %%
print(m)
# Out:
# 15

# %%
m*=10

# %%
print(m)
# Out:
# 150

# %%
m/=10

# %%
print(m)
# Out:
# 1.5

# %%
m = 15
m**=2

# %%
print(m)
# Out:
# 225

# %% [markdown]
# **Python Logical & Boolean Operators**

# %%
a = True
b = True
c = False
d = False

# %%
print ( a and b )
# Out:
# True

# %%
print ( a and c)
# Out:
# False

# %%
print(c and a )
# Out:
# False

# %%
print ( c and d)
# Out:
# False

# %%
print ( a or b )
# Out:
# True

# %%
print( a or c)
# Out:
# True

# %%
print ( c or a)
# Out:
# True

# %%
print ( c or d )
# Out:
# False

# %%
print (not a)
# Out:
# False

# %%
print(not c)
# Out:
# True

# %%
print(( a and b) or print( c and d) or (not a))
# Out:
# True

# %% [markdown]
# **Comparison Operators**

# %%
print ( 2<3)
# Out:
# True

# %%
c = 2<3
print (type (c))
# Out:
# <class 'bool'>

# %%
d = 2==3
print(d)
# Out:
# False

# %%
3 == 3.0
# Out:
# True

# %%
p =12
q =8
r =-3
s =5.56

# %%
print((q<p) and  (r>s))
# Out:
# False

# %%
print (not((p==q) or (r==s)))
# Out:
# True

# %%
True or False and  True
# Out:
# True

# %%
False or True and False
# Out:
# False

# %%
False and False or True
# Out:
# True

# %%
print((not(2!=3) and True) or (False and True))
# Out:
# False

# %% [markdown]
# **Bitwise Operator in Python**

# %%
a = 5
b = 4
print ( a & b)
# Out:
# 4

# %%
print(type( a & b))
# Out:
# <class 'int'>

# %%
print( a|b)
# Out:
# 5

# %%
print( a^b )
# Out:
# 1

# %%
print(~a)
# Out:
# -6

# %%
print(~b)
# Out:
# -5

# %%
print(a << 2)
# Out:
# 20

# %%
print(a>>2)
# Out:
# 1
