# %%
input()
# Out:
#  asdflkjh
# 'asdflkjh'

# %%
a = "sudh"

# %%
a = input()
# Out:
#  sudh

# %%
a = input()
# Out:
#  sudh

# %%
a
# Out:
# 'sudh'

# %%
a = input()
# Out:
#  45

# %%
a
# Out:
# '45'

# %%
b = 34

# %%
a+b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 a+b
#
# TypeError: can only concatenate str (not "int") to str

# %%
int(a)+b
# Out:
# 79

# %%
int('4589')
# Out:
# 4589

# %%
str('4589')
# Out:
# '4589'

# %%
int('4589')
# Out:
# 4589

# %%
str(4589)
# Out:
# '4589'

# %%
a = input()
# Out:
#  asdflkj

# %%
a
# Out:
# 'asdflkj'

# %%
str(a)
# Out:
# 'asdflkj'

# %%
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 int(a)
#
# ValueError: invalid literal for int() with base 10: 'asdflkj'

# %%
Int(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 Int(a)
#
# NameError: name 'Int' is not defined

# %%
a
# Out:
# 'asdflkj'

# %%
str(c)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 str(c)
#
# NameError: name 'c' is not defined

# %%
str(45)
# Out:
# '45'

# %%
a
# Out:
# 'asdflkj'
